# %%
import pandas as pd
from pytrends.request import TrendReq
from IPython.display import display

#hello
#im talking

class therapeuticClassPipeline:

    def __init__(self, mckesson_demand_filename, search_terms_filename, thera_class):
        self.mckesson_demand_filename = mckesson_demand_filename
        self.search_terms_filename = search_terms_filename
        self.thera_class = thera_class

        self.map_thera_search_terms = self.__load_file_name__()
        self.search_terms = self.__load_search_terms__()

        # needs to be implemented
        self.search_term_series_df = self.__load_search_term_pytrend_data()

        # needs to be implemented
        self.demand_time_series_df = self.__load_demand_data()

    def __load_search_terms__(self):
        thera_class_filter = self.map_thera_search_terms["THERA_CLS"].str.strip() == self.thera_class
        search_terms = self.map_thera_search_terms[thera_class_filter]
        return search_terms

    def __load_search_term_pytrend_data(self):
        print()

    def __load_demand_data(self):
        print()

    def __load_file_name__(self):
        map_thera_search_terms = pd.read_csv(self.search_terms_filename)
        return map_thera_search_terms

        # import pdb; pdb.set_trace()

    def Merge_demand_search_term_data(self):
        print()

    def Plot_time_series_data(self):
        print()

    def Write_data(self):
        print()

    def __str__(self):
        print(mckesson_demand_filename)
        print(search_terms_filename)
        print(thera_class)
        print(self.search_terms)
        pd.set_option('display.width', None)
        display(self.search_terms)


if __name__ == '__main__':
    mckesson_demand_filename = "fake_data_web_search_demand_indicator_20210921.csv"
    search_terms_filename = "Copy of list_of_therapeutic_classes - Sheet1.csv"
    thera_class = "ADRENALS"

    tcp = therapeuticClassPipeline(mckesson_demand_filename, search_terms_filename, thera_class)
    tcp.__load_file_name__()
    tcp.__str__()
# Out:
# fake_data_web_search_demand_indicator_20210921.csv
# Copy of list_of_therapeutic_classes - Sheet1.csv
# ADRENALS
#                                   THERA_CLS            Unnamed: 1 Unnamed: 2  \
# 5  ADRENALS                                  low adrenal function    fatigue
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 5     stress        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10
# 5        NaN         NaN
#                                   THERA_CLS            Unnamed: 1 Unnamed: 2  \
# 5  ADRENALS                                  low adrenal function    fatigue
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 5     stress        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10
# 5        NaN         NaN

# %%
# Out:
# Package             Version
# ------------------- -------
# argon2-cffi         21.1.0
# attrs               21.2.0
# backcall            0.2.0
# bleach              4.1.0
# cffi                1.14.6
# colorama            0.4.4
# cycler              0.10.0
# debugpy             1.5.0
# decorator           5.1.0
# defusedxml          0.7.1
# entrypoints         0.3
# ipykernel           6.4.1
# ipython             7.28.0
# ipython-genutils    0.2.0
# ipywidgets          7.6.5
# jedi                0.18.0
# Jinja2              3.0.2
# jsonschema          4.0.1
# jupyter             1.0.0
# jupyter-client      7.0.5
# jupyter-console     6.4.0
# jupyter-core        4.8.1
# jupyterlab-pygments 0.1.2
# jupyterlab-widgets  1.0.2
# kiwisolver          1.3.2
# lab                 6.5
# MarkupSafe          2.0.1
# matplotlib          3.4.3
# matplotlib-inline   0.1.3
# mistune             0.8.4
# nbclient            0.5.4
# nbconvert           6.2.0
# nbformat            5.1.3
# ...

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3    C:\Users\Edward\AppData\Local\Programs\Python\Python38-32\share\jupyter\kernels\python3

# %%
import sys
# !{sys.executable} -m pip install pytrends
# Out:
# ...
#   Using cached pytrends-4.7.3-py3-none-any.whl (14 kB)
# ...
#   Using cached requests-2.26.0-py2.py3-none-any.whl (62 kB)
# ...
#   Using cached lxml-4.6.3-cp38-cp38-win32.whl (3.2 MB)
# ...
#   Using cached urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# ...
#   Using cached idna-3.2-py3-none-any.whl (59 kB)
# ...
#   Using cached certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
# ...
#   Using cached charset_normalizer-2.0.6-py3-none-any.whl (37 kB)
# ...
